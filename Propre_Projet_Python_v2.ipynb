# %% [markdown]
# ## Préparation des données

# %% [markdown]
# Importation des modules utiles (même ceux moins utiles, on sait jamais)

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Lecture des deux datasets pour voir le contenu

# %%
#Dataset 1 
spotify = pd.read_csv("C:\\Users\\laura\\Desktop\\Projet Python S1\\Données\\Final database.csv",sep=",", low_memory=False)
spotify.head()
# Out:
#        Country                                                Uri  Popularity  \
# 0       Global  https://open.spotify.com/track/6FyRXC8tJUh863J...    31833.95
# 1          USA  https://open.spotify.com/track/6FyRXC8tJUh863J...        8.00
# 2    Argentina  https://open.spotify.com/track/6FyRXC8tJUh863J...    76924.40
# 3      Belgium  https://open.spotify.com/track/6FyRXC8tJUh863J...      849.60
# 4  Switzerland  https://open.spotify.com/track/6FyRXC8tJUh863J...    20739.10
#
#         Title        Artist Album/Single              Genre Artist_followers  \
# 0  adan y eva  Paulo Londra       single  argentine hip hop       11427104.0
# 1  adan y eva  Paulo Londra       single  argentine hip hop       11427104.0
# 2  adan y eva  Paulo Londra       single  argentine hip hop       11427104.0
# 3  adan y eva  Paulo Londra       single  argentine hip hop       11427104.0
# 4  adan y eva  Paulo Londra       single  argentine hip hop       11427104.0
#
#   Explicit       Album  ... Sweden Switzerland Taiwan Turkey UK USA Popu_max  \
# 0    False  Adan y Eva  ...      0           0      0      0  0   0       10
# 1    False  Adan y Eva  ...      0           0      0      0  0   1      191
# 2    False  Adan y Eva  ...      0           0      0      0  0   0        1
# 3    False  Adan y Eva  ...      0           0      0      0  0   0      126
# 4    False  Adan y Eva  ...      0           1      0      0  0   0       21
#
#   Top10_dummy Top50_dummy                      Cluster
# 0         1.0         1.0                       global
# 1         0.0         0.0  english speaking and nordic
# 2         1.0         1.0             spanish speaking
# 3         0.0         0.0  english speaking and nordic
# 4         0.0         1.0  english speaking and nordic
#
# [5 rows x 151 columns]

# %%
#Dataset 2
popu = pd.read_csv("C:\\Users\\laura\\Desktop\\Projet Python S1\\Données\\Database to Calculate popularity.csv",sep=",")
popu.head()
# Out:
#    Unnamed: 0 country        date  position  \
# 0           0  Global  05/11/2020       1.0
# 1           1  Global  05/11/2020       2.0
# 2           2  Global  05/11/2020       3.0
# 3           3  Global  05/11/2020       4.0
# 4           4  Global  05/11/2020       5.0
#
#                                                  uri  \
# 0  https://open.spotify.com/track/47EiUVwUp4C9fGc...
# 1  https://open.spotify.com/track/35mvY5S1H3J2QZy...
# 2  https://open.spotify.com/track/3tjFYV6RSFtuktY...
# 3  https://open.spotify.com/track/7hxHWCCAIIxFLCz...
# 4  https://open.spotify.com/track/4y4spB9m0Q6026K...
#
#                                track        title                    artist
# 0   Dakiti , Bad Bunny, Jhay Cortez       Dakiti    Bad Bunny, Jhay Cortez
# 1         positions , Ariana Grande    positions             Ariana Grande
# 2                  Mood  , 24kGoldn        Mood                   24kGoldn
# 3        Lemonade  , Internet Money    Lemonade             Internet Money
# 4           Lonely  , Justin Bieber      Lonely              Justin Bieber

# %% [markdown]
# Merge des deux dataframes

# %%
#Le dataframe que Rodrigue utilise ici c'est dt : dt c'est popularity donc on a déjà chargé popularity

#On drop les colonnes inutiles
dop=pd.DataFrame(spotify)
dop.drop(dop.iloc[:,15:147],1,inplace=True) #je garde que jusqu'à popu_max pour pouvoir l'utiliser
dop

#Renommer les colonnes 
popu.rename(columns={"uri": "Uri"}, inplace=True)
popu.rename(columns={"country": "Country"}, inplace=True)
popu

#On merge sur la gauche
output2 = pd.merge(popu, dop,  
                   on=['Country','Uri'],  
                   how='left') 
output2
# Out:
# C:\Users\laura\AppData\Local\Temp/ipykernel_6892/840302386.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   dop.drop(dop.iloc[:,15:147],1,inplace=True) #je garde que jusqu'à popu_max pour pouvoir l'utiliser
#          Unnamed: 0 Country        date  position  \
# 0                 0  Global  05/11/2020       1.0
# 1                 1  Global  05/11/2020       2.0
# 2                 2  Global  05/11/2020       3.0
# 3                 3  Global  05/11/2020       4.0
# 4                 4  Global  05/11/2020       5.0
# ...             ...     ...         ...       ...
# 9806996     9806996  Taiwan  01/01/2017     197.0
# 9806997     9806997  Taiwan  01/01/2017     198.0
# 9806998     9806998  Taiwan  01/01/2017     199.0
# 9806999     9806999  Taiwan  01/01/2017     200.0
# 9807000     9807000     NaN         NaN       NaN
#
#                                                        Uri  \
# 0        https://open.spotify.com/track/47EiUVwUp4C9fGc...
# 1        https://open.spotify.com/track/35mvY5S1H3J2QZy...
# 2        https://open.spotify.com/track/3tjFYV6RSFtuktY...
# 3        https://open.spotify.com/track/7hxHWCCAIIxFLCz...
# 4        https://open.spotify.com/track/4y4spB9m0Q6026K...
# ...                                                    ...
# 9806996  https://open.spotify.com/track/3zHq9ouUJQFQRf3...
# 9806997  https://open.spotify.com/track/3CRDbSIZ4r5MsZ0...
# 9806998  https://open.spotify.com/track/2mEvsc8k8iwR099...
# 9806999  https://open.spotify.com/track/0L7loeTIg6akW84...
# 9807000                                                NaN
#
#                                                      track  \
# 0                         Dakiti , Bad Bunny, Jhay Cortez
# 1                               positions , Ariana Grande
# 2                                        Mood  , 24kGoldn
# 3                              Lemonade  , Internet Money
# 4                                 Lonely  , Justin Bieber
# ...                                                    ...
# 9806996   Love Me Like You Do - From "Fifty Shades Of G...
# 9806997                  Stressed Out , Twenty One Pilots
# 9806998   The End - From "La La Land" Soundtrack , Just...
# 9806999                Light It Up  - Remix , Major Lazer
# 9807000                                                NaN
#
#                                                      title  \
# 0                                                  Dakiti
# 1                                               positions
# 2                                                   Mood
# 3                                               Lemonade
# 4                                                 Lonely
# ...                                                    ...
# 9806996   Love Me Like You Do - From "Fifty Shades Of G...
# 9806997                                      Stressed Out
# 9806998            The End - From "La La Land" Soundtrack
# 9806999                              Light It Up  - Remix
# 9807000                                                NaN
#
#                            artist  Popularity  \
# 0         Bad Bunny, Jhay Cortez       3160.6
# 1                  Ariana Grande       3713.4
# 2                       24kGoldn      37609.6
# 3                 Internet Money      16001.7
# 4                  Justin Bieber       4932.8
# ...                           ...         ...
# 9806996           Ellie Goulding        311.2
# 9806997        Twenty One Pilots        165.6
# 9806998           Justin Hurwitz        558.4
# 9806999              Major Lazer          0.8
# 9807000                       NaN         NaN
#
#                                                    Title  ...  \
# 0                                                 dakiti  ...
# 1                                              positions  ...
# 2                                                   mood  ...
# 3                                               lemonade  ...
# 4                                                 lonely  ...
# ...                                                  ...  ...
# 9806996  love me like you do - from fifty shades of grey  ...
# 9806997                                     stressed out  ...
# 9806998             the end - from la la land soundtrack  ...
# 9806999                             light it up  - remix  ...
# 9807000                                              NaN  ...
#
#                                               Album Release_date Track_number  \
# 0                                            Dakiti   2020-10-30            1
# 1                                         Positions   2020-10-30           12
# 2                            Mood (feat. iann dior)   2020-07-24            1
# 3                                      B4 The Storm   2020-08-28           17
# 4                        Lonely (with benny blanco)   2020-10-16            1
# ...                                             ...          ...          ...
# 9806996                           Delirium (Deluxe)   2015-11-06            9
# 9806997                                  Blurryface   2015-05-15            2
# 9806998  La La Land (Original Motion Picture Score)   2016-12-09           28
# 9806999              Peace Is The Mission: Extended   2015-06-01           10
# 9807000                                         NaN          NaN          NaN
#
#         Tracks_in_album        danceability              energy Popu_max  \
# 0                     1               0.731               0.573      1.0
# 1                    14               0.737               0.802      1.0
# 2                     1                 0.7               0.722      1.0
# 3                    17                 0.8  0.6579999999999999      2.0
# 4                     1               0.631               0.239      5.0
# ...                 ...                 ...                 ...      ...
# 9806996              22               0.262               0.606    125.0
# 9806997              14  0.7340000000000001               0.637    121.0
# 9806998              30               0.215              0.0474    121.0
# 9806999              14               0.746               0.877    200.0
# 9807000             NaN                 NaN                 NaN      NaN
#
#         Top10_dummy Top50_dummy                      Cluster
# 0               1.0         1.0                       global
# 1               1.0         1.0                       global
# 2               1.0         1.0                       global
# 3               1.0         1.0                       global
# 4               1.0         1.0                       global
# ...             ...         ...                          ...
# 9806996         0.0         0.0  english speaking and nordic
# 9806997         0.0         0.0  english speaking and nordic
# 9806998         0.0         0.0  english speaking and nordic
# 9806999         0.0         0.0  english speaking and nordic
# 9807000         NaN         NaN                          NaN
#
# [9807001 rows x 25 columns]

# %% [markdown]
# Pour date, on ne garde que les 4 derniers chiffres

# %%
output2['date']=output2['date'].str[-4:]
output2
# Out:
#          Unnamed: 0 Country  date  position  \
# 0                 0  Global  2020       1.0
# 1                 1  Global  2020       2.0
# 2                 2  Global  2020       3.0
# 3                 3  Global  2020       4.0
# 4                 4  Global  2020       5.0
# ...             ...     ...   ...       ...
# 9806996     9806996  Taiwan  2017     197.0
# 9806997     9806997  Taiwan  2017     198.0
# 9806998     9806998  Taiwan  2017     199.0
# 9806999     9806999  Taiwan  2017     200.0
# 9807000     9807000     NaN   NaN       NaN
#
#                                                        Uri  \
# 0        https://open.spotify.com/track/47EiUVwUp4C9fGc...
# 1        https://open.spotify.com/track/35mvY5S1H3J2QZy...
# 2        https://open.spotify.com/track/3tjFYV6RSFtuktY...
# 3        https://open.spotify.com/track/7hxHWCCAIIxFLCz...
# 4        https://open.spotify.com/track/4y4spB9m0Q6026K...
# ...                                                    ...
# 9806996  https://open.spotify.com/track/3zHq9ouUJQFQRf3...
# 9806997  https://open.spotify.com/track/3CRDbSIZ4r5MsZ0...
# 9806998  https://open.spotify.com/track/2mEvsc8k8iwR099...
# 9806999  https://open.spotify.com/track/0L7loeTIg6akW84...
# 9807000                                                NaN
#
#                                                      track  \
# 0                         Dakiti , Bad Bunny, Jhay Cortez
# 1                               positions , Ariana Grande
# 2                                        Mood  , 24kGoldn
# 3                              Lemonade  , Internet Money
# 4                                 Lonely  , Justin Bieber
# ...                                                    ...
# 9806996   Love Me Like You Do - From "Fifty Shades Of G...
# 9806997                  Stressed Out , Twenty One Pilots
# 9806998   The End - From "La La Land" Soundtrack , Just...
# 9806999                Light It Up  - Remix , Major Lazer
# 9807000                                                NaN
#
#                                                      title  \
# 0                                                  Dakiti
# 1                                               positions
# 2                                                   Mood
# 3                                               Lemonade
# 4                                                 Lonely
# ...                                                    ...
# 9806996   Love Me Like You Do - From "Fifty Shades Of G...
# 9806997                                      Stressed Out
# 9806998            The End - From "La La Land" Soundtrack
# 9806999                              Light It Up  - Remix
# 9807000                                                NaN
#
#                            artist  Popularity  \
# 0         Bad Bunny, Jhay Cortez       3160.6
# 1                  Ariana Grande       3713.4
# 2                       24kGoldn      37609.6
# 3                 Internet Money      16001.7
# 4                  Justin Bieber       4932.8
# ...                           ...         ...
# 9806996           Ellie Goulding        311.2
# 9806997        Twenty One Pilots        165.6
# 9806998           Justin Hurwitz        558.4
# 9806999              Major Lazer          0.8
# 9807000                       NaN         NaN
#
#                                                    Title  ...  \
# 0                                                 dakiti  ...
# 1                                              positions  ...
# 2                                                   mood  ...
# 3                                               lemonade  ...
# 4                                                 lonely  ...
# ...                                                  ...  ...
# 9806996  love me like you do - from fifty shades of grey  ...
# 9806997                                     stressed out  ...
# 9806998             the end - from la la land soundtrack  ...
# 9806999                             light it up  - remix  ...
# 9807000                                              NaN  ...
#
#                                               Album Release_date Track_number  \
# 0                                            Dakiti   2020-10-30            1
# 1                                         Positions   2020-10-30           12
# 2                            Mood (feat. iann dior)   2020-07-24            1
# 3                                      B4 The Storm   2020-08-28           17
# 4                        Lonely (with benny blanco)   2020-10-16            1
# ...                                             ...          ...          ...
# 9806996                           Delirium (Deluxe)   2015-11-06            9
# 9806997                                  Blurryface   2015-05-15            2
# 9806998  La La Land (Original Motion Picture Score)   2016-12-09           28
# 9806999              Peace Is The Mission: Extended   2015-06-01           10
# 9807000                                         NaN          NaN          NaN
#
#         Tracks_in_album        danceability              energy Popu_max  \
# 0                     1               0.731               0.573      1.0
# 1                    14               0.737               0.802      1.0
# 2                     1                 0.7               0.722      1.0
# 3                    17                 0.8  0.6579999999999999      2.0
# 4                     1               0.631               0.239      5.0
# ...                 ...                 ...                 ...      ...
# 9806996              22               0.262               0.606    125.0
# 9806997              14  0.7340000000000001               0.637    121.0
# 9806998              30               0.215              0.0474    121.0
# 9806999              14               0.746               0.877    200.0
# 9807000             NaN                 NaN                 NaN      NaN
#
#         Top10_dummy Top50_dummy                      Cluster
# 0               1.0         1.0                       global
# 1               1.0         1.0                       global
# 2               1.0         1.0                       global
# 3               1.0         1.0                       global
# 4               1.0         1.0                       global
# ...             ...         ...                          ...
# 9806996         0.0         0.0  english speaking and nordic
# 9806997         0.0         0.0  english speaking and nordic
# 9806998         0.0         0.0  english speaking and nordic
# 9806999         0.0         0.0  english speaking and nordic
# 9807000         NaN         NaN                          NaN
#
# [9807001 rows x 25 columns]

# %% [markdown]
# ## Les quêtes

# %% [markdown]
# Quête 1 : L’utilisateur entre un titre de chanson et un artiste : dans quels pays la chanson a été classée ainsi que si
# cette chanson a déjà été classée dans le classement global. Si la chanson a déjà été classée, donner quelle a
# été sa plus haute position (dans les classements globaux et des pays). Prendre en compte le cas où
# l’utilisateur entre un titre qui n’a jamais été classé.

# %%
def quete1(titre,artiste): #Definition de la fonction et des termes à entrer dans la fonction
    
    #Création des inputs à mettre dans la formule
    
    titre = input("Titre :")
    artiste = input("Artiste :")
    
    #Boucle if pour vérifier si c'est dans la base de données
    
    if titre in list(output2.Title) and artiste in list(output2.Artist): #Si le titre au final est classé dans la base de données
        quete1=output2.loc[(output2['Title']==titre) & (output2['Artist']==artiste)] #On localise dans la dataframe
        quete1=quete1.sort_values(by=['Popu_max'], ascending=[True]) #On trie par truc maximum
        quete1=quete1.drop(columns=['Unnamed: 0','Uri','track','Album/Single','Explicit','Genre','Top10_dummy','Top50_dummy','Cluster','danceability','energy','Release_date'])
        print(quete1.head(1))
        pays = list(quete1['Country'])
        country = []
        for i in pays:
            if i not in country:
                country.append(i)
        country.sort()
        print(str(country).strip('[]')) 
        if 'Global' in country:
            print ("\n" + "La chanson a été classée mondialement")
        else: print("\n" +"La chanson n'a pas été classée mondialement")
    else: print("La quête n'est pas disponible dans la base de données")
    return
quete1(titre,artiste)
# Out:
# Titre :shape of you
# Artiste :Ed Sheeran
#     Country  date  position           title        artist  Popularity  \
# 163  Global  2020     164.0   Shape of You    Ed Sheeran     221571.0
#
#             Title      Artist Artist_followers       Album Track_number  \
# 163  shape of you  Ed Sheeran       71783101.0  ÷ (Deluxe)            4
#
#     Tracks_in_album  Popu_max
# 163              16       1.0
# 'Argentina', 'Australia', 'Austria', 'Belgium', 'Brazil', 'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Denmark', 'Ecuador', 'Finland', 'France', 'Germany', 'Global', 'Indonesia', 'Ireland', 'Italy', 'Malaysia', 'Mexico', 'Netherlands', 'New Zealand', 'Norway', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Singapore', 'Spain', 'Sweden', 'Switzerland', 'Taiwan', 'Turkey', 'UK', 'USA'
#
# La chanson a été classée mondialement

# %% [markdown]
# Quête 2 : L’utilisateur entre un artiste et un pays : combien de ses chansons ont été classées dans le classement du
# pays entré, pendant l’année donnée ainsi que la liste des chansons ordonnées par popularité.

# %%
def quete2(artiste,pays,date):
    
    artiste = input("Artiste : ")
    pays = input("Pays : ")
    date = input("Année : ")
    
    if artiste in list(output2.Artist) and pays in list(output2.Country) and date in list(output2.date):
        quete2=output2.loc[(output2['Artist']==artiste) & (output2['Country']==pays) &(output2['date']==date)]
        quete2=quete2.sort_values(by=['Popularity'], ascending=[False])
        title = list(quete2['Title'])
        titre = []
        for i in title:
            if i not in titre:
                titre.append(i)
        titre.sort()
        print("La liste des chansons qui ont été classés est la suivante : " +str(titre).strip('[]')) 
        print("La chanson a donc été classée " + str(len(titre)) + " fois en " + str(date) + " en " + str(pays))
        mycolumns = ['Title','Album/Single','Popularity']
        print(quete2[mycolumns].drop_duplicates())
    
    else: print("La quête n'est pas disponible dans la base de données")
    return
quete2(artiste,pays,date)
# Out:
# Artiste : Ariana Grande
# Pays : France
# Année : 2020
# La liste des chansons qui ont été classés est la suivante : '34+35', '7 rings', 'just like magic', 'love language', 'my hair', 'nasty', 'obvious', 'positions', 'pov', 'shut up', 'six thirty', 'west side'
# La chanson a donc été classée 12 fois en 2020 en France
#                    Title Album/Single  Popularity
# 5105530          7 rings        album    31160.70
# 5043618        positions        album     1308.00
# 5045222        positions       single     1204.00
# 5044089            34+35        album      751.10
# 5044879          shut up        album      102.85
# 5044900  just like magic        album       85.00
# 5044921              pov        album       63.20
# 5044927            nasty        album       58.40
# 5044929          my hair        album       56.80
# 5044933       six thirty        album       53.60
# 5044965        west side        album       28.00
# 5044967    love language        album       26.40
# 5044978          obvious        album       17.60

# %% [markdown]
# Quête 3 : L’utilisateur entre un genre, un pays et une année : les 10 chansons les plus populaires cette année là, puis
# les 10 artistes les plus populaires pour cette même année pour le genre mentionné, dans le pays en question
# avec, pour chaque artiste, son nombre d’abonnés sur Spotify.

# %%
def quete3(genre,pays,annee):
    
    genre = input("Genre (en minuscules) :")
    pays = input("Pays :")
    annee = input("Année :")
    
    if genre in list(output2.Genre) and pays in list(output2.Country) and annee in list(output2.date):
        quete3=output2.loc[(output2['Genre']==genre) & (output2['Country']==pays) & (output2['date']==annee)]
        quete3=quete3.sort_values(by=['Popularity'], ascending=[False])
        quete3=quete3.drop_duplicates(subset="Title") #suppression des doublons 
        mycolumns=["position","title","artist"]
        print("Les 10 chansons les plus populaires pour le genre " + genre +  " lors de l'année " + str(annee) + " sont les suivants" )
        print(quete3[mycolumns].head(10))
        quete3pt2=quete3.sort_values(by=['Popularity'], ascending=[False])
        quete3pt2=quete3pt2.drop_duplicates(subset="Artist")
        mycolumn=["artist","Artist_followers"]
        print("Les 10 artistes les plus populaires pour le genre " + genre +  " lors de l'année " + str(annee) + " sont les suivants")
        print(quete3pt2[mycolumn].head(10))
    else: print("La quête n'est pas disponible dans la base de données")
    return
quete3(genre,pays,annee)
# Out:
# Genre (en minuscules) :rap
# Pays :France
# Année :2020
# Les 10 chansons les plus populaires pour le genre rap lors de l'année 2020 sont les suivants
#          position                           title  \
# 5076673      74.0            HIGHEST IN THE ROOM
# 5078646      47.0                     SICKO MODE
# 5076621      22.0                     THE SCOTTS
# 5078045      46.0                     goosebumps
# 5082640      41.0                     STARGAZING
# 5099921     122.0                        No Idea
# 5081518     119.0               BUTTERFLY EFFECT
# 5104740     141.0   HIGHEST IN THE ROOM  - REMIX
# 5082478      79.0                       YOSEMITE
# 5081535     136.0                      OUT WEST
#
#                                        artist
# 5076673                         Travis Scott
# 5078646                         Travis Scott
# 5076621   THE SCOTTS, Travis Scott, Kid Cudi
# 5078045                         Travis Scott
# 5082640                         Travis Scott
# 5099921                          Don Toliver
# 5081518                         Travis Scott
# 5104740                         Travis Scott
# 5082478                         Travis Scott
# 5081535               JACKBOYS, Travis Scott
# Les 10 artistes les plus populaires pour le genre rap lors de l'année 2020 sont les suivants
#                                        artist Artist_followers
# 5076673                         Travis Scott          13434540
# 5076621   THE SCOTTS, Travis Scott, Kid Cudi            159323
# 5099921                          Don Toliver         1012488.0
# 5104740                         Travis Scott        13434540.0
# 5081535               JACKBOYS, Travis Scott          327979.0
# 5104586                  JACKBOYS, Sheck Wes          327979.0
# 5050959                         Travis Scott        13434540.0
# 5091195                          Don Toliver         1012488.0

# %% [markdown]
# ## Partie de tests : vérification des procédés

# %%
genre = input("Genre (en minuscules) :")
pays = input("Pays :")
annee = input("Année :")
quete3=output2.loc[(output2['Genre']==genre) & (output2['Country']==pays) & (output2['date']==annee)]
quete3=quete3.sort_values(by=['Popularity'], ascending=[False])
quete3=quete3.drop_duplicates(subset='Title')
quete3.head(5)
# Out:
# Genre (en minuscules) :k-pop
# Pays :France
# Année :2020
#          Unnamed: 0 Country  date  position  \
# 5043652     5043652  France  2020      53.0
# 5064785     5064785  France  2020     186.0
# 5057504     5057504  France  2020     105.0
# 5049926     5049926  France  2020     127.0
# 5094570     5094570  France  2020     171.0
#
#                                                        Uri  \
# 5043652  https://open.spotify.com/track/0t1kP63rueHleOh...
# 5064785  https://open.spotify.com/track/3vAn0qZzdyuHamc...
# 5057504  https://open.spotify.com/track/2J4P46vCFm1rPkN...
# 5049926  https://open.spotify.com/track/4Ws314Ylb27BVsv...
# 5094570  https://open.spotify.com/track/2QyuXBcV1LJ2rq0...
#
#                                    track                title       artist  \
# 5043652                  Dynamite , BTS             Dynamite          BTS
# 5064785   How You Like That , BLACKPINK    How You Like That    BLACKPINK
# 5057504          Ice Cream  , BLACKPINK           Ice Cream     BLACKPINK
# 5049926      Lovesick Girls , BLACKPINK       Lovesick Girls    BLACKPINK
# 5094570                        ON , BTS                   ON          BTS
#
#          Popularity              Title  ...                          Album  \
# 5043652      7582.5           dynamite  ...     Dynamite (DayTime Version)
# 5064785      1067.6  how you like that  ...              How You Like That
# 5057504       411.2          ice cream  ...  Ice Cream (with Selena Gomez)
# 5049926       342.4     lovesick girls  ...                      THE ALBUM
# 5094570       232.8                 on  ...            MAP OF THE SOUL : 7
#
#         Release_date Track_number Tracks_in_album        danceability  \
# 5043652   2020-08-28            1               6               0.746
# 5064785   2020-06-26            1               1               0.828
# 5057504   2020-08-28            1               1                0.79
# 5049926   2020-10-02            5               8  0.6579999999999999
# 5094570   2020-02-21           11              20               0.583
#
#                      energy Popu_max Top10_dummy Top50_dummy  \
# 5043652               0.765     50.0         0.0         1.0
# 5064785               0.782     62.0         0.0         0.0
# 5057504  0.7290000000000001    105.0         0.0         0.0
# 5049926               0.733    112.0         0.0         0.0
# 5094570  0.8170000000000001    118.0         0.0         0.0
#
#                                          Cluster
# 5043652  southern europe and portuguese heritage
# 5064785  southern europe and portuguese heritage
# 5057504  southern europe and portuguese heritage
# 5049926  southern europe and portuguese heritage
# 5094570  southern europe and portuguese heritage
#
# [5 rows x 25 columns]
